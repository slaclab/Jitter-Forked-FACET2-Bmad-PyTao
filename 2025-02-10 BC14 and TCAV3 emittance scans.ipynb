# %%
from UTILITY_quickstart import *

importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_baseline.yml")

# %%
csrTF = False
trackEnd = "PR15944"

bunchCount = importedDefaultSettings["bunchCount"]

tao = initializeTao(
    inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"],
    
    csrTF = csrTF,
    numMacroParticles=1e4,
    scratchPath = "/tmp",
    randomizeFileNames = True
)

setLattice(tao, **importedDefaultSettings)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_configs/defaults.yml
# Number of macro particles = 10000.0
# Beam created, written to /tmp/beams/activeBeamFile_8147169738808091527.h5, and reinit to tao

# %%
# trackBeam(tao, 
#           **importedDefaultSettings,
#           trackEnd = trackEnd,
#           verbose = True
#          )

# P = getBeamAtElement(tao, trackEnd)

# display(plotMod(P, 'x', 'y', bins=300))
# plt.clf()

# getBeamSpecs(P)

# %%
setQuadkG(tao, "Q14901", -31.3)
print(f"""{getQuadkG(tao, "Q14901")}""")
# print(f"""{tao.cmd("show ele Q14901 -all")}""")

getMatrix(tao, "IM14890", "PR15944", print = True)
tao.cmd("show ele Q14901 -all")
# Out:
# -31.29999999999999
# <style type="text/css">
# </style>
# <table id="T_077c4">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_077c4_row0_col0" class="data row0 col0" >-1.561529</td>
#       <td id="T_077c4_row0_col1" class="data row0 col1" >-6.216709</td>
#       <td id="T_077c4_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_077c4_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_077c4_row0_col4" class="data row0 col4" >-0.000000</td>
#       <td id="T_077c4_row0_col5" class="data row0 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_077c4_row1_col0" class="data row1 col0" >-0.061052</td>
#       <td id="T_077c4_row1_col1" class="data row1 col1" >-0.755226</td>
#       <td id="T_077c4_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_077c4_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_077c4_row1_col4" class="data row1 col4" >-0.000000</td>
# ...

# %%
setQuadkG(tao, "Q14901", 50000)
print(f"""{getQuadkG(tao, "Q14901")}""")
# print(f"""{tao.cmd("show ele Q14901 -all")}""")

getMatrix(tao, "IM14890", "PR15944", print = True)
tao.cmd("show ele Q14901 -all")
# Out:
# 50000.00000000004
# <style type="text/css">
# </style>
# <table id="T_4b02f">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4b02f_row0_col0" class="data row0 col0" >-101.914815</td>
#       <td id="T_4b02f_row0_col1" class="data row0 col1" >-21.220174</td>
#       <td id="T_4b02f_row0_col2" class="data row0 col2" >-0.000000</td>
#       <td id="T_4b02f_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_4b02f_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_4b02f_row0_col5" class="data row0 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4b02f_row1_col0" class="data row1 col0" >-12.836760</td>
#       <td id="T_4b02f_row1_col1" class="data row1 col1" >-2.680651</td>
#       <td id="T_4b02f_row1_col2" class="data row1 col2" >-0.000000</td>
#       <td id="T_4b02f_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_4b02f_row1_col4" class="data row1 col4" >-0.000000</td>
# ...

# %%
tao.cmd(f"set ele TCY15280 VOLTAGE = 20e6")

#The zero-crossing is off by about two degrees. Not sure the origin of this error. Maybe due to the element length?
tao.cmd(f"set ele TCY15280 PHI0 = {2/360.0}")

tao.cmd("show ele TCY15280 -all")

# %%
trackBeam(tao, 
          **importedDefaultSettings,
          trackEnd = trackEnd,
          verbose = True
         )

# %%
P = getBeamAtElement(tao, trackEnd)

display(plotMod(P, 'x', 'y', bins=300))
display(plotMod(P, 'y', 'delta_t', bins=300))
plt.clf()

# %%
# Out:
# -5000.000000000005
# <style type="text/css">
# </style>
# <table id="T_b0b56">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b0b56_row0_col0" class="data row0 col0" >-1.560789</td>
#       <td id="T_b0b56_row0_col1" class="data row0 col1" >-6.216556</td>
#       <td id="T_b0b56_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_b0b56_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_b0b56_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_b0b56_row0_col5" class="data row0 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b0b56_row1_col0" class="data row1 col0" >-0.060959</td>
#       <td id="T_b0b56_row1_col1" class="data row1 col1" >-0.755207</td>
#       <td id="T_b0b56_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_b0b56_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_b0b56_row1_col4" class="data row1 col4" >-0.000000</td>
# ...

# %%
tao.cmd("show lat IM14890:PR15944")
# Out:
# ['# Values shown are for the Exit End of each Element:',
#  '# Index  name      key                       s       l    beta   phi_a    eta   orbit    beta   phi_b    eta   orbit  Track',
#  '#                                                            a   [2pi]      x  x [mm]       b   [2pi]      y  y [mm]  State',
#  '    717  IM14890   Marker              422.458   0.000 1079.58   5.365   0.00   0.000 1124.25   4.917  -0.00  -0.000  Alive',
#  '    718  DM24B     Drift               422.611   0.153 1083.33   5.365   0.00   0.000 1143.46   4.917  -0.00  -0.000  Alive',
#  '    719  Q14901#1  Quadrupole          422.665   0.053 1090.69   5.365   0.00   0.000 1143.80   4.917  -0.00  -0.000  Alive',
#  '    720  BPM14901  Monitor             422.665   0.000 1090.69   5.365   0.00   0.000 1143.80   4.917  -0.00  -0.000  Alive',
#  '    721  Q14901#2  Quadrupole          422.718   0.053 1110.30   5.365   0.00   0.000 1131.44   4.917  -0.00  -0.000  Alive',
# ...
