# %%
from UTILITY_quickstart import *

importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_baseline.yml")

# %%
csrTF = True
trackEnd = "PR15944"

bunchCount = importedDefaultSettings["bunchCount"]

tao = initializeTao(
    inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"],
    
    csrTF = csrTF,
    numMacroParticles=1e4,
    scratchPath = "/tmp",
    randomizeFileNames = True
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR on
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_configs/defaults.yml
# Number of macro particles = 10000.0
# Beam created, written to /tmp/beams/activeBeamFile_13289984144731358395.h5, and reinit to tao

# %%
trackBeam(tao, 
          **importedDefaultSettings,
          trackEnd = trackEnd,
          verbose = True
         )

P = getBeamAtElement(tao, trackEnd)

display(plotMod(P, 'x', 'y', bins=300))
plt.clf()
# Out:
# Loaded /tmp/beams/activeBeamFile_13289984144731358395.h5
# Set track_start = L0AFEND, track_end = PR15944
# Set track_end = BEGBC14_1
# Tracking!
# Beam centered at BEGBC14 written to /tmp/beams/patchBeamFile_13289984144731358395.h5
# Loaded /tmp/beams/patchBeamFile_13289984144731358395.h5
# Set track_start = BEGBC14_1, track_end = PR15944
# Tracking!
# trackBeam() exiting

# %%
tao.cmd("show ele XTCAVF")
# Out:
# ['Element # 1496',
#  'Element Name: XTCAVF',
#  'Element Type:  "TRANS_DEFL"',
#  'Element Alias:  "TCAV:LI20:2400"',
#  'Key: Crab_Cavity',
#  'S_start, S:    986.097939,    987.131389',
#  'Ref_time_start, Ref_time:  3.289286E-06,  3.292733E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0334498E+00 m',
#  '    4  HARMON                      =  3.8872616E+04           5  HARMON_MASTER               =  F (0)',
#  '    8  VOLTAGE                     =  2.0000000E+07 Volt      6  GRADIENT                    =  1.9352657E+07 eV/m',
#  '   15  RF_FREQUENCY                =  1.1424000E+10 Hz       16  RF_WAVELENGTH               =  2.6242337E-02 m',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   53  P0C                         =  1.0018436E+10 eV           BETA                        =  1.0000000E+00',
# ...

# %%
tao.cmd(f"set ele TCY15280 VOLTAGE = 0")
tao.cmd("show ele TCY15280 -all")
# Out:
# ['Element # 751',
#  'Element Name: TCY15280',
#  'Element Type:  "LOLA"',
#  'Element Alias:  "LI15:ACCL:280"',
#  'Key: Lcavity',
#  'S_start, S:    445.103670,    447.541670',
#  'Ref_time_start, Ref_time:  1.484723E-06,  1.492855E-06',
#  '',
#  'Attribute values:',
#  '    1  L                           =  2.4380000E+00 m        31  L_ACTIVE                    =  2.4380000E+00 m',
#  '    2  TILT                        =  0.0000000E+00 rad      60  TILT_TOT                    =  0.0000000E+00 rad',
#  '    7  GRADIENT_ERR                =  0.0000000E+00 eV/m',
#  '    8  VOLTAGE                     =  0.0000000E+00 Volt      6  GRADIENT                    =  0.0000000E+00 eV/m',
#  '    9  VOLTAGE_ERR                 =  0.0000000E+00 Volt',
#  '   10  FRINGE_TYPE                 =  Full (4)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
# ...

# %%
tao.cmd(f"set ele TCY15280 VOLTAGE = 20e6")
tao.cmd("show ele TCY15280 -all")
# Out:
# ['Element # 751',
#  'Element Name: TCY15280',
#  'Element Type:  "LOLA"',
#  'Element Alias:  "LI15:ACCL:280"',
#  'Key: Lcavity',
#  'S_start, S:    445.103670,    447.541670',
#  'Ref_time_start, Ref_time:  1.484723E-06,  1.492855E-06',
#  '',
#  'Attribute values:',
#  '    1  L                           =  2.4380000E+00 m        31  L_ACTIVE                    =  2.4380000E+00 m',
#  '    2  TILT                        =  0.0000000E+00 rad      60  TILT_TOT                    =  0.0000000E+00 rad',
#  '    7  GRADIENT_ERR                =  0.0000000E+00 eV/m',
#  '    8  VOLTAGE                     =  2.0000000E+07 Volt      6  GRADIENT                    =  8.2034454E+06 eV/m',
#  '    9  VOLTAGE_ERR                 =  0.0000000E+00 Volt',
#  '   10  FRINGE_TYPE                 =  Full (4)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
# ...

# %%
trackBeam(tao, 
          **importedDefaultSettings,
          trackEnd = trackEnd,
          verbose = True
         )

P = getBeamAtElement(tao, trackEnd)

display(plotMod(P, 'x', 'y', bins=300))
plt.clf()
# Out:
# Loaded /tmp/beams/activeBeamFile_13289984144731358395.h5
# Set track_start = L0AFEND, track_end = PR15944
# Set track_end = BEGBC14_1
# Tracking!
# Beam centered at BEGBC14 written to /tmp/beams/patchBeamFile_13289984144731358395.h5
# Loaded /tmp/beams/patchBeamFile_13289984144731358395.h5
# Set track_start = BEGBC14_1, track_end = PR15944
# Tracking!
# trackBeam() exiting
