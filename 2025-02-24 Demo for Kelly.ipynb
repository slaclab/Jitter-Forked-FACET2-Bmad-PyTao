# %%
from UTILITY_quickstart import *

#Load a the settings for a known-good lattice
importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_baseline.yml")

#Initialize Bmad/Tao
tao = initializeTao(
    inputBeamFilePathSuffix = "/PEXT_demo.h5" #Import some arbitrary OpenPMD beam
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_configs/defaults.yml
# Number of macro particles defined by input file
# Beam created, written to /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/beams/activeBeamFile.h5, and reinit to tao

# %%
#Load the known-good settings into Tao
setLattice(tao, **importedDefaultSettings)

# %%
#Particle tracking
trackBeam(tao, 
          trackStart = "PEXT", #The element where you load the external beam
          trackEnd = "end",
          **importedDefaultSettings,
          verbose = True
         )
# Out:
# Loaded /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao/beams/activeBeamFile.h5
# Set track_start = PEXT, track_end = end
# Tracking!
# trackBeam() exiting

# %%
#Look at the beam anywhere downstream
P = getBeamAtElement(tao, "DTOTR")
display(plotMod(P, 'x', 'y', bins=300))
display(plotMod(P, 'z', 'pz', bins=300))
plt.clf()
