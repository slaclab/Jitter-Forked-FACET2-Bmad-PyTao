# %%
from UTILITY_quickstart import *

# %%
tao = initializeTao(
    #inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights_driverOnly_2023-05-16InjectorMatch.h5',
    inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',

    #runImpactTF=True,
    #impactGridCount=8,
    numMacroParticles=1e4,

    lastTrackedElement = "end"
)

tao.cmd("set beam add_saved_at = SYAG, M11E")
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# No defaults file provided to setLattice(). Using setLattice_defaults.yml
# Loading default setLattice() values
# Number of macro particles = 10000.0
# []

# %%
tao.cmd("show ele SYAG")
# Out:
# ['Element # 1452',
#  'Element Name: SYAG',
#  'Element Type:  "YAG"',
#  'Key: Monitor',
#  'S_start, S:    971.785132,    971.785132',
#  'Ref_time_start, Ref_time:  3.241543E-06,  3.241543E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  0.0000000E+00 m',
#  '    7  OSC_AMPLITUDE               =  0.0000000E+00 m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   24  TILT_CALIB                  =  0.0000000E+00 rad',
#  '   25  DE_ETA_MEAS                 =  0.0000000E+00',
#  '   53  P0C                         =  9.9984356E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  9.9984356E+09 eV           GAMMA                       =  1.9566450E+04',
# ...

# %%
tao.cmd("show ele M11E")
# Out:
# ['Element # 1456',
#  'Element Name: M11E',
#  'Element Type:  "R45"',
#  'Key: Monitor',
#  'S_start, S:    972.773148,    972.773148',
#  'Ref_time_start, Ref_time:  3.244839E-06,  3.244839E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  0.0000000E+00 m',
#  '    7  OSC_AMPLITUDE               =  0.0000000E+00 m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   24  TILT_CALIB                  =  0.0000000E+00 rad',
#  '   25  DE_ETA_MEAS                 =  0.0000000E+00',
#  '   53  P0C                         =  9.9984356E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  9.9984356E+09 eV           GAMMA                       =  1.9566450E+04',
# ...

# %%
tao.cmd("show ele MFFF")
# Out:
# ['Element # 1468',
#  'Element Name: MFFF',
#  'Key: Marker',
#  'S_start, S:    979.004697,    979.004697',
#  'Ref_time_start, Ref_time:  3.265625E-06,  3.265625E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  0.0000000E+00 m',
#  '    7  OSC_AMPLITUDE               =  0.0000000E+00 m',
#  '   24  TILT_CALIB                  =  0.0000000E+00 rad',
#  '   25  DE_ETA_MEAS                 =  0.0000000E+00',
#  '   53  P0C                         =  9.9984356E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  9.9984356E+09 eV           GAMMA                       =  1.9566450E+04',
#  '   64  REF_TIME_START              =  3.2656252E-06 sec      50  DELTA_REF_TIME              =  0.0000000E+00 sec',
#  '',
#  '       TRACKING_METHOD              =  Bmad_Standard             APERTURE_AT                =  Exit_End',
# ...

# %%
trackBeam(tao)

# %%
P = getBeamAtElement(tao, "SYAG")
display(plotMod(P, 'energy', 'x',  bins=300))
display(plotMod(P, 'energy', 'px',  bins=300))
display(plotMod(P, 'x', 'px',  bins=300))
plt.clf()
print(P)
# Out:
# ParticleGroup with 10000 particles with total charge 1.9999999999999956e-09 C

# %%
P = getBeamAtElement(tao, "M11E")
display(plotMod(P, 'energy', 'x',  bins=300))
display(plotMod(P, 'energy', 'px',  bins=300))
display(plotMod(P, 'x', 'px',  bins=300))
plt.clf()
print(P)
# Out:
# ParticleGroup with 10000 particles with total charge 1.9999999999999956e-09 C

# %%
tao.cmd("show matrix SYAG M11E")
# Out:
# ['Symplectic Error:  2.22E-16',
#  '',
#  '     0.77695208     0.88709146     0.00000000     0.00000000     0.00000000    -0.00000000   :  4.58094156E-32',
#  '    -0.46069232     0.76108140     0.00000000     0.00000000     0.00000000     0.00000000   : -1.40159348E-31',
#  '    -0.00000000     0.00000000     1.23828120     1.09425047     0.00000000     0.00000000   : -8.83875022E-34',
#  '     0.00000000    -0.00000000     0.50717414     1.25575317     0.00000000     0.00000000   : -9.62964972E-35',
#  '    -0.00000000    -0.00000000     0.00000000     0.00000000     1.00000000     0.00000000   : -4.31780463E-48',
#  '     0.00000000     0.00000000     0.00000000     0.00000000     0.00000000     1.00000000   :  0.00000000E+00']

# %%
tao.cmd("show matrix BEGBC20 SYAG")
# Out:
# ['Symplectic Error:  3.26E-14',
#  '',
#  '    -0.42535588     2.88362111    -0.00000000    -0.00000000     0.00000000     0.11177114   : -1.35207165E-17',
#  '    -0.37467227     0.18904842    -0.00000000    -0.00000000     0.00000000     0.03801490   : -3.96574311E-18',
#  '    -0.00000000    -0.00000000     0.06074739    13.74947745     0.00000000    -0.00000000   : -5.33267048E-19',
#  '     0.00000000     0.00000000    -0.09930225    -6.01431627     0.00000000     0.00000000   : -1.42844252E-20',
#  '    -0.02570768    -0.08849042     0.00000000     0.00000000     1.00000000    -0.00693627   : -1.52052422E-16',
#  '     0.00000000     0.00000000     0.00000000     0.00000000     0.00000000     1.00000000   :  0.00000000E+00']

# %%
tao.cmd("show matrix BEGBC20 MFFF")
# Out:
# ['Symplectic Error:  3.31E-14',
#  '',
#  '    -1.21868291    -4.97352885    -0.00000000    -0.00000000     0.00000000     0.00065500   :  6.59506910E-18',
#  '    -0.08919805    -1.18458137     0.00000000     0.00000000     0.00000000     0.00002466   :  4.25325063E-18',
#  '    -0.00000000    -0.00000000    -0.61830047     6.83251047     0.00000000    -0.00000000   : -2.47221407E-18',
#  '    -0.00000000    -0.00000000    -0.09363957    -0.58257541     0.00000000    -0.00000000   : -2.87359815E-19',
#  '    -0.00002838    -0.00065327     0.00000000     0.00000000     1.00000000    -0.00704089   : -1.69495577E-16',
#  '     0.00000000     0.00000000     0.00000000     0.00000000     0.00000000     1.00000000   :  0.00000000E+00']
