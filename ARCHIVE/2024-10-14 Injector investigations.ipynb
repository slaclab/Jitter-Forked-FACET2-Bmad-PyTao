# %%
from UTILITY_quickstart import *

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    #inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',

    csrTF = False,
    #numMacroParticles=1e4,
    loadDefaultLatticeTF=False,
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Base Tao lattice
# Number of macro particles defined by input file

# %% [markdown]
# # Summary

# %% [raw]
# Golden lattice - BMAD
# L0AFEND
# Beta (m)        48.8     51.2
# Alpha           -3.16    -4.39
#
# PR10571
# Beta (m)         5.74     2.58
# Alpha           -2.14     0.010
#
#
# Golden lattice - Lucretia live model
# L0AFEND
# Beta (m)        48.83          46.43
# Alpha           -3.16          -4.09
#
# PR10571
# Beta (m)         5.737         2.58
# Alpha           -2.039         0.052
#
# Golden lattice - Beam (OpenPMD .twiss())
# L0AFEND
# Beta (m)        36.2          36.4
# Alpha           -7.99         -8.02
#
# PR10571 (tracked)
# Beta (m)         19.6          36.9
# Alpha            0.87          13.5

# %% [markdown]
# # Golden lattice - BMAD

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    #inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',

    csrTF = False,
    #numMacroParticles=1e4,
    loadDefaultLatticeTF=False,
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Base Tao lattice
# Number of macro particles defined by input file

# %%
tao.cmd("show ele L0AFEND")
# Out:
# ['Element # 37',
#  'Element Name: L0AFEND',
#  'Key: Marker',
#  'S_start, S:      4.127448,      4.127448',
#  'Ref_time_start, Ref_time:  1.378376E-08,  1.378376E-08',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  0.0000000E+00 m',
#  '    7  OSC_AMPLITUDE               =  0.0000000E+00 m',
#  '   24  TILT_CALIB                  =  0.0000000E+00 rad',
#  '   25  DE_ETA_MEAS                 =  0.0000000E+00',
#  '   53  P0C                         =  6.3997960E+07 eV           BETA                        =  9.9996812E-01',
#  '   54  E_TOT                       =  6.4000000E+07 eV           GAMMA                       =  1.2524488E+02',
#  '   64  REF_TIME_START              =  1.3783756E-08 sec      50  DELTA_REF_TIME              =  0.0000000E+00 sec',
#  '',
#  '       TRACKING_METHOD              =  Bmad_Standard             APERTURE_AT                =  Exit_End',
# ...

# %%
tao.cmd("show ele PR10571")
# Out:
# ['Element # 124',
#  'Element Name: PR10571',
#  'Element Type:  "OTR"',
#  'Element Alias:  "OTRS:IN10:571"',
#  'Key: Monitor',
#  'S_start, S:     14.236682,     14.236682',
#  'Ref_time_start, Ref_time:  4.750495E-08,  4.750495E-08',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  0.0000000E+00 m',
#  '    7  OSC_AMPLITUDE               =  0.0000000E+00 m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   24  TILT_CALIB                  =  0.0000000E+00 rad',
#  '   25  DE_ETA_MEAS                 =  0.0000000E+00',
#  '   53  P0C                         =  1.2499896E+08 eV           BETA                        =  9.9999164E-01',
#  '   54  E_TOT                       =  1.2500000E+08 eV           GAMMA                       =  2.4461890E+02',
# ...

# %% [markdown]
# # Golden lattice - Lucretia live model

# %% [markdown]
# ![image.png](attachment:a42cba07-5f23-4275-8f31-219c5945f5ec.png)
# ![image.png](attachment:2de15daf-d80a-4c86-a51a-d7aa4484b83c.png)

# %% [markdown]
# # Beams

# %% [markdown]
# ## Golden lattice

# %%
POld = ParticleGroup("./beams/L0AFEND_facet2-lattice.h5")

# %%
print(POld.twiss(plane="x"))
print(POld.twiss(plane="y"))
# Out:
# {'alpha_x': -7.990788473328799, 'beta_x': 36.23004898433273, 'gamma_x': 1.790025192997371, 'emit_x': 3.045268971323036e-08, 'eta_x': -0.0017376422414646206, 'etap_x': -0.0004062503450052696, 'norm_emit_x': 3.6946218044711316e-06}
# {'alpha_y': -8.019313309992421, 'beta_y': 36.37269082964837, 'gamma_y': 1.7955610232330173, 'emit_y': 3.0511848423318116e-08, 'eta_y': -0.0017629506825284854, 'etap_y': -0.00040771104033566775, 'norm_emit_y': 3.7017991363348466e-06}

# %%
tao = initializeTao(
    #inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',

    csrTF = False,
    #numMacroParticles=1e4,
    loadDefaultLatticeTF=False,
)

trackBeam(tao, trackEnd = "PR10571")
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Base Tao lattice
# Number of macro particles defined by input file

# %%
#Sanity check that this is the same as the directly imported beam
POld_L0AFEND = getBeamAtElement(tao,"L0AFEND")
print(POld_L0AFEND.twiss(plane="x"))
print(POld_L0AFEND.twiss(plane="y"))
# Out:
# {'alpha_x': -7.990788473328799, 'beta_x': 36.23004898433273, 'gamma_x': 1.790025192997371, 'emit_x': 3.045268971323036e-08, 'eta_x': -0.001737642241464688, 'etap_x': -0.00040625034500528073, 'norm_emit_x': 3.6946218044711316e-06}
# {'alpha_y': -8.019313309992421, 'beta_y': 36.37269082964837, 'gamma_y': 1.7955610232330173, 'emit_y': 3.0511848423318116e-08, 'eta_y': -0.0017629506825283347, 'etap_y': -0.0004077110403356306, 'norm_emit_y': 3.7017991363348466e-06}

# %%
POld_L0AFEND["mean_energy"]

# %%
display(plotMod(POld_L0AFEND, 'x', 'y',  bins=300))
display(plotMod(POld_L0AFEND, 'x', 'xp',  bins=300))
plt.clf()

# %%
POld_10571 = getBeamAtElement(tao,"PR10571")
print(POld_10571.twiss(plane="x"))
print(POld_10571.twiss(plane="y"))

# %%
display(plotMod(POld_10571, 'x', 'y',  bins=300))
display(plotMod(POld_10571, 'x', 'xp',  bins=300))
plt.clf()

# %% [markdown]
# # Quasi-golden lattice

# %%
#Load a defaultsFile that /should/ duplicate the golden lattice (except for the linacs; those are only approximate)
tao = initializeTao(
    #inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',

    csrTF = False,
    #numMacroParticles=1e4,
    defaultsFile="setLattice_defaults_clean.yml",
)

trackBeam(tao, trackEnd = "PR10571")
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Overwriting lattice with setLattice() defaults
# Number of macro particles defined by input file

# %%
#Sanity check that this is the same as the directly imported beam
PQuasiGold_L0AFEND = getBeamAtElement(tao,"L0AFEND")
print(PQuasiGold_L0AFEND.twiss(plane="x"))
print(PQuasiGold_L0AFEND.twiss(plane="y"))
# Out:
# {'alpha_x': -7.990788473328799, 'beta_x': 36.23004898433273, 'gamma_x': 1.790025192997371, 'emit_x': 3.045268971323036e-08, 'eta_x': -0.001737642241464688, 'etap_x': -0.00040625034500528073, 'norm_emit_x': 3.6946218044711316e-06}
# {'alpha_y': -8.019313309992421, 'beta_y': 36.37269082964837, 'gamma_y': 1.7955610232330173, 'emit_y': 3.0511848423318116e-08, 'eta_y': -0.0017629506825283347, 'etap_y': -0.0004077110403356306, 'norm_emit_y': 3.7017991363348466e-06}

# %%
PQuasiGold_L0AFEND["mean_energy"]
# Out:
# 61998201.5093176

# %%
PQuasiGold_10571 = getBeamAtElement(tao,"PR10571")
print(PQuasiGold_10571.twiss(plane="x"))
print(PQuasiGold_10571.twiss(plane="y"))

# %% [markdown]
# ## Two bunch

# %%
PNew = ParticleGroup("./beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5")

PDrive, PWitness = getDriverAndWitness(PNew)

# %%
print(PNew.twiss(plane="x"))
print(PNew.twiss(plane="y"))

print(PDrive.twiss(plane="x"))
print(PDrive.twiss(plane="y"))

print(PWitness.twiss(plane="x"))
print(PWitness.twiss(plane="y"))
# Out:
# {'alpha_x': -3.030938164685405, 'beta_x': 27.51674005857946, 'gamma_x': 0.37019596567255597, 'emit_x': 6.300605715999176e-08, 'eta_x': 0.002215804516135024, 'etap_x': 0.00022592469112862727, 'norm_emit_x': 8.126310139575012e-06}
# {'alpha_y': -3.0099975655096225, 'beta_y': 27.31566362201247, 'gamma_y': 0.36828998495452553, 'emit_y': 6.261330578452872e-08, 'eta_y': -0.0011068075212432567, 'etap_y': -0.00011109366348633346, 'norm_emit_y': 8.075654383150628e-06}
# {'alpha_x': -1.9638317690372737, 'beta_x': 20.262741445675964, 'gamma_x': 0.23968302759528454, 'emit_x': 5.0876645602090324e-08, 'eta_x': 0.004256108212952794, 'etap_x': 0.00048501100497719095, 'norm_emit_x': 6.581618220639036e-06}
# {'alpha_y': -1.9702291419198918, 'beta_y': 20.310818220886834, 'gamma_y': 0.24035481084903523, 'emit_y': 5.097982646413291e-08, 'eta_y': -8.043488851474089e-05, 'etap_y': 3.193184598802076e-05, 'norm_emit_y': 6.5949661336864485e-06}
# ...

# %%
PNew["mean_energy"]
# Out:
# 65908913.38664049

# %%
display(plotMod(PNew, 'x', 'y',  bins=300))
display(plotMod(PDrive, 'x', 'y',  bins=300))
display(plotMod(PWitness, 'x', 'y',  bins=300))



display(plotMod(PNew, 'x', 'xp',  bins=300))
display(plotMod(PDrive, 'x', 'xp',  bins=300))
display(plotMod(PWitness, 'x', 'xp',  bins=300))
plt.clf()

# %% [markdown]
# # 2024-10-14 new two bunch

# %%
PNew = ParticleGroup("./beams/2024-10-14_Impact_TwoBunch/2024-10-14_TwoBunch.h5")

PDrive, PWitness = getDriverAndWitness(PNew)

# %%
print(PNew.twiss(plane="x"))
print(PNew.twiss(plane="y"))

print(PDrive.twiss(plane="x"))
print(PDrive.twiss(plane="y"))

print(PWitness.twiss(plane="x"))
print(PWitness.twiss(plane="y"))
# Out:
# {'alpha_x': -4.0831849212138, 'beta_x': 13.587460824594048, 'gamma_x': 1.3006402983580077, 'emit_x': 5.0775599329390406e-08, 'eta_x': -1.970391384447674e-06, 'etap_x': -4.678191168822377e-07, 'norm_emit_x': 6.781555890453639e-06}
# {'alpha_y': -4.081373755930435, 'beta_y': 13.580340982324163, 'gamma_y': 1.3002333121517653, 'emit_y': 5.081953352797323e-08, 'eta_y': 2.628107759129375e-06, 'etap_y': 5.193531693256448e-07, 'norm_emit_y': 6.7874237133277505e-06}
# {'alpha_x': -3.488797080050547, 'beta_x': 10.48910619145347, 'gamma_x': 1.2557509501144661, 'emit_x': 4.1933068909816324e-08, 'eta_x': -2.0898204302583993e-06, 'etap_x': -5.381332393640118e-07, 'norm_emit_x': 5.581442047318276e-06}
# {'alpha_y': -3.487635510243327, 'beta_y': 10.484478866315106, 'gamma_y': 1.2555322606069341, 'emit_y': 4.1974359529477325e-08, 'eta_y': 4.079727007475401e-06, 'etap_y': 8.880286064732366e-07, 'norm_emit_y': 5.5869379770636366e-06}
# ...

# %%
PNew["mean_energy"]
# Out:
# 68250599.24405333

# %%
display(plotMod(PNew, 'x', 'y',  bins=300))
display(plotMod(PDrive, 'x', 'y',  bins=300))
display(plotMod(PWitness, 'x', 'y',  bins=300))



display(plotMod(PNew, 'x', 'xp',  bins=300))
display(plotMod(PDrive, 'x', 'xp',  bins=300))
display(plotMod(PWitness, 'x', 'xp',  bins=300))
plt.clf()
