# %%
from UTILITY_quickstart import *

# ?initializeTao
# Out:
# Signature:
# initializeTao(
#     filePath=None,
#     lastTrackedElement='end',
#     csrTF=False,
#     inputBeamFilePathSuffix=None,
#     numMacroParticles=None,
#     loadDefaultLatticeTF=True,
#     runImpactTF=False,
#     impactGridCount=32,
# )
# Docstring: <no docstring>
# File:      ~/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py
# Type:      function

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = '/beams/2024-07-01_Impact_TwoBunch/2024-07-01_twobunch_nudgeWeights.h5'
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Loading default setLattice() values
# Number of macro particles defined by input file

# %%
trackBeam(tao)

# %%
P =  getBeamAtElement(tao, "PENT")
PDriver, PWitness = getDriverAndWitness(P)

display(plotMod(P, 'x', 'y',  bins=300));
display(plotMod(PDriver, 'x', 'y',  bins=300));
display(plotMod(PWitness, 'x', 'y',  bins=300));

print(P)
# Out:
# ParticleGroup with 90396 particles with total charge 1.447067552e-09 C

# %%
P =  getBeamAtElement(tao, "MFFF")
PDriver, PWitness = getDriverAndWitness(P)

display(plotMod(P, 'x', 'y',  bins=300));
display(plotMod(PDriver, 'x', 'y',  bins=300));
display(plotMod(PWitness, 'x', 'y',  bins=300));

print(P)
# Out:
# ParticleGroup with 90396 particles with total charge 1.447067552e-09 C

# %%
P =  getBeamAtElement(tao, "L0AFEND")
PDriver, PWitness = getDriverAndWitness(P)

display(plotMod(P, 'x', 'y',  bins=300));
display(plotMod(PDriver, 'x', 'y',  bins=300));
display(plotMod(PWitness, 'x', 'y',  bins=300));

print(P)
print(PDriver)
print(PWitness)
# Out:
# ParticleGroup with 100000 particles with total charge 1.6008067200000007e-09 C
# ParticleGroup with 75210 particles with total charge 1.2045633600000001e-09 C
# ParticleGroup with 24790 particles with total charge 3.9624336000000015e-10 C
