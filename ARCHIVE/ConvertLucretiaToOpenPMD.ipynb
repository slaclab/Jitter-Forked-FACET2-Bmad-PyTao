# %%
#This isn't currently working!


import pmd_beamphysics as pmd

importFilePath = "/Users/nmajik/Documents/SLAC/slacsync/bmadExample/bmad/beams/nmm_2023-11-18_beamAtL0AFEND_2bunch_2nC_2e6particles/nmm_2023-11-18_beamAtL0AFEND_2bunch_2nC_2e6particles_preloadFile.mat"

elementNames = pmd.interfaces.lucretia.list_element_names(importFilePath)

print(elementNames)

beamData = pmd.interfaces.lucretia.lucretia_to_data(
    importFilePath,
    ele_name = "L0AFEND"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 5
#       1 import pmd_beamphysics as pmd
#       3 importFilePath = "/Users/nmajik/Documents/SLAC/slacsync/bmadExample/bmad/beams/nmm_2023-11-18_beamAtL0AFEND_2bunch_2nC_2e6particles/nmm_2023-11-18_beamAtL0AFEND_2bunch_2nC_2e6particles_preloadFile.mat"
# ----> 5 elementNames = pmd.interfaces.lucretia.list_element_names(importFilePath)
#       7 print(elementNames)
#       9 beamData = pmd.interfaces.lucretia.lucretia_to_data(
#      10     importFilePath,
#      11     ele_name = "L0AFEND"
#      12 )
#
# File /opt/homebrew/anaconda3/envs/bmad/lib/python3.11/site-packages/pmd_beamphysics/interfaces/lucretia.py:220, in list_element_names(filePath)
#     205 """
#     206 Find the element names in a Lucretia beam file
#     207
#    (...)
#     217
#     218 """
#     219 dat = sio.loadmat(filePath)
# ...

# %%
dir(pmd.interfaces.lucretia)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'list_element_names',
#  'lucretia_to_data',
#  'np',
#  'sio',
#  'write_lucretia']

# %%
import scipy.io as sio
import numpy as np

# %%
raw = sio.loadmat(importFilePath)

# %%
print(raw)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Mon Nov 20 09:14:24 2023', '__version__': '1.0', '__globals__': ['BEAMLINE', 'PS', 'WF'], 'BEAMLINE': array([[array([[(array(['DL00'], dtype='<U4'), array([[0]], dtype=uint8), array([[0.006]]), array(['DRIF'], dtype='<U4'), array([[-0.869048]]), array([[(array([[0]], dtype=uint8), array([[0]], dtype=uint8))]],
#                       dtype=[('ZMotion', 'O'), ('LorentzDelay', 'O')]), array([[  10.19510189,    0.        , 1002.27394414]]), array([[-0.61086524,  0.        ,  0.        ]]), array([[  10.69356734,    0.        , 1001.56206169]]), array([[-0.61086524,  0.        ,  0.        ]]))]],
#               dtype=[('Name', 'O'), ('S', 'O'), ('P', 'O'), ('Class', 'O'), ('L', 'O'), ('TrackFlag', 'O'), ('Coordi', 'O'), ('Anglei', 'O'), ('Coordf', 'O'), ('Anglef', 'O')])                                                                                                              ],
# ...

# %%
raw['Beam']
# Out:
# array([[(array([[1]], dtype=uint8), array([[(array([[-3.65927646e-03, -5.67220933e-03,  2.21672504e-03, ...,
#                         -9.23652336e-05, -4.05304112e-04,  1.85829577e-04],
#                        [-3.30175445e-04, -5.18194110e-04,  2.04800819e-04, ...,
#                         -4.01890111e-06, -6.16805465e-05,  3.41950655e-05],
#                        [ 4.71854614e-03,  5.82993265e-04,  3.20134502e-03, ...,
#                         -4.08810466e-04,  3.77016665e-04, -3.58956262e-04],
#                        [ 4.24405236e-04,  5.05763450e-05,  2.97950477e-04, ...,
#                         -6.51542293e-05,  5.05498612e-05, -5.18391713e-05],
#                        [-2.13267701e-03, -2.04158543e-03, -2.06136873e-03, ...,
#                          1.69993869e-03,  1.69756496e-03,  1.69749785e-03],
#                        [ 6.45303304e-02,  6.46115759e-02,  6.46001830e-02, ...,
# ...
