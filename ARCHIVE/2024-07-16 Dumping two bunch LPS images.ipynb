# %%
from UTILITY_quickstart import *
# ?initializeTao
# Out:
# Signature:
# initializeTao(
#     filePath=None,
#     lastTrackedElement='end',
#     csrTF=False,
#     inputBeamFilePathSuffix=None,
#     numMacroParticles=None,
#     loadDefaultLatticeTF=True,
#     runImpactTF=False,
#     impactGridCount=32,
# )
# Docstring: <no docstring>
# File:      ~/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py
# Type:      function

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    #inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',

    csrTF = True,
    #numMacroParticles=1e4,
    #loadDefaultLatticeTF=False,
    lastTrackedElement = "PR10711"

)

tao.cmd("set beam add_saved_at = PR10711")

trackBeam(tao)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to PR10711
# CSR on
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_defaults.yml
# Number of macro particles defined by input file

# %%
selectMarkers  = np.array(["ENDDL10", "BEGBC11_1", "BC11CEND", "BEGBC14_1", "ENDBC14_2", "BEGBC20", "ENDBC20", "PENT"])

for markerString in selectMarkers:
    P = getBeamAtElement(tao, markerString)
    plt.clf()
    img = plotMod(P, 'delta_t', 'energy',  bins=300)
    img.savefig(f'{markerString}.png')
    print(P)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 6
#       4 P = getBeamAtElement(tao, markerString)
#       5 plt.clf()
# ----> 6 img = plotMod(P, 'delta_t', 'energy',  bins=300)
#       7 img.savefig(f'{markerString}.png')
#       8 print(P)
#
# File ~/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_plotMod.py:51, in plotMod(particle_group, key1, key2, bins, xlim, ylim, tex, nice, **kwargs)
#      48     bins = int(np.sqrt(n/4) )
#      50 # Scale to nice units and get the factor, unit prefix
# ---> 51 x = particle_group[key1]
#      52 y = particle_group[key2]
#      54 # Form nice arrays
#
# File /opt/homebrew/anaconda3/envs/bmad/lib/python3.11/site-packages/pmd_beamphysics/particles.py:742, in ParticleGroup.__getitem__(self, key)
#     740     return self.cov(*subkeys)[0,1]
#     741 elif key.startswith('delta_'):
# --> 742     return self.delta(key[6:])
# ...

# %%
tao.cmd(f"""show lat {", ".join(selectMarkers)} -att s""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tao.cmd(f"""show lat {", ".join(selectMarkers)} -att s""")
#
# NameError: name 'selectMarkers' is not defined

# %%
trackBeam(tao)
setLinacPhase(tao, ["L0BF*"], 4)

markerString = "PR10711"
P = getBeamAtElement(tao, markerString)
plt.clf()
img = plotMod(P, 'delta_t', 'energy',  bins=300)
img.savefig(f'{markerString}.png')
display(img)
print(P)
# Out:
# ParticleGroup with 100000 particles with total charge 2.099311454754768e-09 C
