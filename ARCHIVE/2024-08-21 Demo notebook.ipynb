# %% [markdown]
# # Import and startup

# %%
from UTILITY_quickstart import *

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    defaultsFile = "setLattice_defaults_2024-08-21_demo.yml",
    csrTF = True,
    numMacroParticles = 1e4,
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR on
# Overwriting lattice with setLattice() defaults
# Number of macro particles = 10000.0

# %% [markdown]
# # Transport matrices (to arb. order)

# %%
transportMatrix = getMatrix(tao, "BEGBC20", "PENT", print = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_09151">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_09151_row0_col0" class="data row0 col0" >-0.234101</td>
#       <td id="T_09151_row0_col1" class="data row0 col1" >-2.303850</td>
#       <td id="T_09151_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_09151_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_09151_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_09151_row0_col5" class="data row0 col5" >0.001606</td>
#     </tr>
#     <tr>
#       <td id="T_09151_row1_col0" class="data row1 col0" >0.657682</td>
#       <td id="T_09151_row1_col1" class="data row1 col1" >2.200762</td>
#       <td id="T_09151_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_09151_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_09151_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_09151_row1_col5" class="data row1 col5" >-0.024145</td>
#     </tr>
#     <tr>
#       <td id="T_09151_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_09151_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_09151_row2_col2" class="data row2 col2" >0.177864</td>
#       <td id="T_09151_row2_col3" class="data row2 col3" >1.164147</td>
#       <td id="T_09151_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_09151_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_09151_row3_col0" class="data row3 col0" >-0.000000</td>
#       <td id="T_09151_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_09151_row3_col2" class="data row3 col2" >0.046266</td>
#       <td id="T_09151_row3_col3" class="data row3 col3" >5.925082</td>
#       <td id="T_09151_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_09151_row3_col5" class="data row3 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_09151_row4_col0" class="data row4 col0" >-0.004596</td>
#       <td id="T_09151_row4_col1" class="data row4 col1" >-0.052093</td>
#       <td id="T_09151_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_09151_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_09151_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_09151_row4_col5" class="data row4 col5" >-0.007197</td>
#     </tr>
#     <tr>
#       <td id="T_09151_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_09151_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_09151_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_09151_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_09151_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_09151_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Move a sextupole
setXOffset(tao, "S1EL", 0.001)
transportMatrixMod = getMatrix(tao, "BEGBC20", "PENT", print = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_78ebf">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_78ebf_row0_col0" class="data row0 col0" >-0.263797</td>
#       <td id="T_78ebf_row0_col1" class="data row0 col1" >-2.386678</td>
#       <td id="T_78ebf_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_78ebf_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_78ebf_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_78ebf_row0_col5" class="data row0 col5" >-0.001195</td>
#     </tr>
#     <tr>
#       <td id="T_78ebf_row1_col0" class="data row1 col0" >0.665485</td>
#       <td id="T_78ebf_row1_col1" class="data row1 col1" >2.230124</td>
#       <td id="T_78ebf_row1_col2" class="data row1 col2" >-0.000000</td>
#       <td id="T_78ebf_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_78ebf_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_78ebf_row1_col5" class="data row1 col5" >-0.023090</td>
#     </tr>
#     <tr>
#       <td id="T_78ebf_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_78ebf_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_78ebf_row2_col2" class="data row2 col2" >0.183901</td>
#       <td id="T_78ebf_row2_col3" class="data row2 col3" >1.219787</td>
#       <td id="T_78ebf_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_78ebf_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_78ebf_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_78ebf_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_78ebf_row3_col2" class="data row3 col2" >-0.073969</td>
#       <td id="T_78ebf_row3_col3" class="data row3 col3" >4.947084</td>
#       <td id="T_78ebf_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_78ebf_row3_col5" class="data row3 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_78ebf_row4_col0" class="data row4 col0" >-0.006886</td>
#       <td id="T_78ebf_row4_col1" class="data row4 col1" >-0.057774</td>
#       <td id="T_78ebf_row4_col2" class="data row4 col2" >-0.000000</td>
#       <td id="T_78ebf_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_78ebf_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_78ebf_row4_col5" class="data row4 col5" >-0.007383</td>
#     </tr>
#     <tr>
#       <td id="T_78ebf_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_78ebf_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_78ebf_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_78ebf_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_78ebf_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_78ebf_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Impact at IP
displayMatrix(transportMatrixMod - transportMatrix)
# Out:
# <style type="text/css">
# </style>
# <table id="T_93397">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_93397_row0_col0" class="data row0 col0" >-0.029695</td>
#       <td id="T_93397_row0_col1" class="data row0 col1" >-0.082828</td>
#       <td id="T_93397_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_93397_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_93397_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_93397_row0_col5" class="data row0 col5" >-0.002801</td>
#     </tr>
#     <tr>
#       <td id="T_93397_row1_col0" class="data row1 col0" >0.007803</td>
#       <td id="T_93397_row1_col1" class="data row1 col1" >0.029362</td>
#       <td id="T_93397_row1_col2" class="data row1 col2" >-0.000000</td>
#       <td id="T_93397_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_93397_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_93397_row1_col5" class="data row1 col5" >0.001055</td>
#     </tr>
#     <tr>
#       <td id="T_93397_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_93397_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_93397_row2_col2" class="data row2 col2" >0.006037</td>
#       <td id="T_93397_row2_col3" class="data row2 col3" >0.055640</td>
#       <td id="T_93397_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_93397_row2_col5" class="data row2 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_93397_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_93397_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_93397_row3_col2" class="data row3 col2" >-0.120235</td>
#       <td id="T_93397_row3_col3" class="data row3 col3" >-0.977997</td>
#       <td id="T_93397_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_93397_row3_col5" class="data row3 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_93397_row4_col0" class="data row4 col0" >-0.002290</td>
#       <td id="T_93397_row4_col1" class="data row4 col1" >-0.005681</td>
#       <td id="T_93397_row4_col2" class="data row4 col2" >-0.000000</td>
#       <td id="T_93397_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_93397_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_93397_row4_col5" class="data row4 col5" >-0.000186</td>
#     </tr>
#     <tr>
#       <td id="T_93397_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_93397_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_93397_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_93397_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_93397_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_93397_row5_col5" class="data row5 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
setXOffset(tao, "S1EL", 0.00)

# %% [markdown]
# # Track and plot

# %%
trackBeam(tao)

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'x', 'y',  bins=300));
plt.clf()

# %% [markdown]
# # Change a magnet

# %%
setQuadkG(tao, "Q0FF", 0)
trackBeam(tao)

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'x', 'y',  bins=300));

# %% [markdown]
# # Change linac phase

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'z', 'pz',  bins=300));

# %%
setLinacPhase(tao, "L2", -37)
trackBeam(tao)

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'z', 'pz',  bins=300));
