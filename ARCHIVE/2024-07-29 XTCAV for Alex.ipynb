# %%
from UTILITY_quickstart import *

# %%
tao = initializeTao(
    #inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights_driverOnly_2023-05-16InjectorMatch.h5',
    inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',
    loadDefaultLatticeTF=False,
    numMacroParticles=1e4
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# Base Tao lattice
# Number of macro particles = 10000.0

# %%
trackBeam(tao)

P = getBeamAtElement(tao, "DTOTR")

display(plotMod(P, 'x', 'y',  bins=100))
plt.clf()

# %%
tao.cmd("set ele XTCAVF VOLTAGE = 10e6")
tao.cmd("set ele XTCAVF PHI0 = 0.0")

trackBeam(tao)

P = getBeamAtElement(tao, "DTOTR")

display(plotMod(P, 'x', 'y',  bins=100))
plt.clf()

# %%
tao.cmd("show ele XTCAVF")
# Out:
# ['Element # 1496',
#  'Element Name: XTCAVF',
#  'Element Type:  "TRANS_DEFL"',
#  'Element Alias:  "TCAV:LI20:2400"',
#  'Key: Crab_Cavity',
#  'S_start, S:    986.097939,    987.131389',
#  'Ref_time_start, Ref_time:  3.289286E-06,  3.292733E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0334498E+00 m',
#  '    4  HARMON                      =  3.8872616E+04           5  HARMON_MASTER               =  F (0)',
#  '    8  VOLTAGE                     =  1.0000000E+07 Volt      6  GRADIENT                    =  9.6763287E+06 eV/m',
#  '   15  RF_FREQUENCY                =  1.1424000E+10 Hz       16  RF_WAVELENGTH               =  2.6242337E-02 m',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   53  P0C                         =  1.0000000E+10 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  1.0000000E+10 eV           GAMMA                       =  1.9569512E+04',
#  '   64  REF_TIME_START              =  3.2892857E-06 sec      50  DELTA_REF_TIME              =  3.4472175E-09 sec',
#  '   65  INTEGRATOR_ORDER            = 0',
#  '   67  DS_STEP                     =  1.0334498E-01 m        66  NUM_STEPS                   = 10',
#  '   68  CSR_DS_STEP                 =  0.0000000E+00 m',
#  '',
#  '       TRACKING_METHOD              =  Bmad_Standard             APERTURE_AT                =  Exit_End',
#  '       MAT6_CALC_METHOD             =  Auto                      APERTURE_TYPE              =  Rectangular',
#  '       SPIN_TRACKING_METHOD         =  Tracking                  OFFSET_MOVES_APERTURE      =  F',
#  '       PTC_INTEGRATION_TYPE         =  Matrix_Kick               SYMPLECTIFY                =  F',
#  '       CSR_METHOD                   =  Off                       FIELD_MASTER               =  F',
#  '       SPACE_CHARGE_METHOD          =  Off                       LONGITUDINAL ORIENTATION   =       1',
#  '       FIELD_CALC                   =  Bmad_Standard             REF_SPECIES                =  Electron',
#  '',
#  'Slave_status: Free',
#  '',
#  'Lord_status:  Not_a_Lord',
#  '',
#  'Twiss at end of element:',
#  '                          A              B            Cbar                        C_mat',
#  '  Beta (m)        71.42669677     9.97901180  |  -0.00000000  -0.00000000      0.00000000  -0.00000000',
#  '  Alpha           -1.45695738    -2.97449656  |   0.00000000   0.00000000      0.00000000  -0.00000000',
#  '  Gamma (1/m)      0.04371929     0.98683416  |   Gamma_c =   1.00000000       Mode_Flip = F',
#  '  Phi (rad)       71.53939267    58.82191630            X              Y              Z',
#  '  Eta (m)          0.00285767     0.00000000     0.00285767     0.00000000     0.02273090',
#  '  Etap             0.00544329     0.00000000     0.00544329     0.00000000    -0.00000000',
#  '  dEta/ds          0.00544329     0.00000000     0.00544329     0.00000000    -0.00000000',
#  '',
#  'Tracking: Electron,   State: Alive',
#  '         Position[mm] Momentum[mrad]        Spin   |',
#  '  X:       0.00000000     0.00000000               | t_particle [sec]:        3.29273289E-06  E_tot: 1.00000E+10',
#  '  Y:       0.00000000    -0.00000000               | t_part-t_ref [sec]:     -1.27054942E-21  PC:    1.00000E+10',
#  '  Z:      -0.00000000     0.00000000               | (t_ref-t_part)*Vel [m]:  3.80901133E-13  Beta:  0.999999999']
