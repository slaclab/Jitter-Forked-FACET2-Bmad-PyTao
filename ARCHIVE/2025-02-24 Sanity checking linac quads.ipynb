# %%
from UTILITY_quickstart import *

importedDefaultSettings = loadConfig("setLattice_configs/2024-10-22_oneBunch_baseline.yml")

csrTF = True



inputBeamFilePathSuffix = importedDefaultSettings["inputBeamFilePathSuffix"]

tao = initializeTao(

    inputBeamFilePathSuffix = inputBeamFilePathSuffix,
    
    csrTF = csrTF,
    numMacroParticles=1e5,
    scratchPath = "/tmp",
    randomizeFileNames = True
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR on
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_configs/defaults.yml
# Number of macro particles = 100000.0
# Beam created, written to /tmp/beams/activeBeamFile_1848459045902829147.h5, and reinit to tao

# %%
setLattice(tao, **importedDefaultSettings)

# %%
tao.cmd("show lat QUAD::*")
# Out:
# ['# Values shown are for the Exit End of each Element:',
#  '# Index  name      key                       s       l    beta   phi_a    eta   orbit    beta   phi_b    eta   orbit  Track',
#  '#                                                            a   [2pi]      x  x [mm]       b   [2pi]      y  y [mm]  State',
#  '     41  QA10361   Quadrupole            4.466   0.108   59.66   0.376   0.00   0.000   45.97   0.431   0.00   0.000  Alive',
#  '     45  QA10371#1 Quadrupole            4.741   0.054  113.38   0.376   0.00   0.000   16.83   0.432   0.00   0.000  Alive',
#  '     47  QA10371#2 Quadrupole            4.795   0.054  113.24   0.376   0.00   0.000   14.50   0.433   0.00   0.000  Alive',
#  '     68  QE10425#1 Quadrupole            8.052   0.054    8.80   0.860   0.00   0.000   84.96   0.919   0.00   0.000  Alive',
#  '     70  QE10425#2 Quadrupole            8.106   0.054   11.48   0.861   0.00   0.000   77.69   0.919   0.00   0.000  Alive',
# ...

# %% [markdown]
# ## Test single magnet

# %%
tao.cmd("show ele Q18501")
# Out:
# ['Element # 1748',
#  'Element Name: Q18501',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:501"',
#  'Key: Quadrupole',
#  'S_start, S:    777.340170,    777.446970',
#  'Ref_time_start, Ref_time:  2.592945E-06,  2.593301E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          = -7.6880833E-01 1/m^2    45  B1_GRADIENT                 =  2.1855405E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.5223916E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.5223917E+09 eV           GAMMA                       =  1.6677904E+04',
# ...

# %%
setLattice(tao, **(importedDefaultSettings | {"L2PhaseSet" : -35} ) )

# %%
tao.cmd("show ele Q18501")
# Out:
# ['Element # 1748',
#  'Element Name: Q18501',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:501"',
#  'Key: Quadrupole',
#  'S_start, S:    777.340170,    777.446970',
#  'Ref_time_start, Ref_time:  2.592945E-06,  2.593301E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          = -7.6880833E-01 1/m^2    45  B1_GRADIENT                 =  2.1855391E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.5223859E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.5223859E+09 eV           GAMMA                       =  1.6677893E+04',
# ...

# %%
tao.cmd("set ele Q18501 FIELD_MASTER = T")
# Out:
# []

# %%
tao.cmd("show ele Q18501")
# Out:
# ['Element # 1748',
#  'Element Name: Q18501',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:501"',
#  'Key: Quadrupole',
#  'S_start, S:    777.340170,    777.446970',
#  'Ref_time_start, Ref_time:  2.592945E-06,  2.593301E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          = -7.6880833E-01 1/m^2    45  B1_GRADIENT                 =  2.1855391E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.5223859E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.5223859E+09 eV           GAMMA                       =  1.6677893E+04',
# ...

# %%
setLattice(tao, **(importedDefaultSettings | {"L2PhaseSet" : -30} ) )

# %%
tao.cmd("show ele Q18501")
# Out:
# ['Element # 1748',
#  'Element Name: Q18501',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:501"',
#  'Key: Quadrupole',
#  'S_start, S:    777.340170,    777.446970',
#  'Ref_time_start, Ref_time:  2.592945E-06,  2.593301E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          = -7.6880694E-01 1/m^2    45  B1_GRADIENT                 =  2.1855391E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.5224013E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.5224013E+09 eV           GAMMA                       =  1.6677923E+04',
# ...

# %%
## Try all magnets

# %%
tao.cmd("show ele Q18601")
# Out:
# ['Element # 1749',
#  'Element Name: Q18601',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:601"',
#  'Key: Quadrupole',
#  'S_start, S:    789.684570,    789.791370',
#  'Ref_time_start, Ref_time:  2.634121E-06,  2.634478E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          =  7.6991010E-01 1/m^2    45  B1_GRADIENT                 = -2.2259583E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.6675772E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.6675772E+09 eV           GAMMA                       =  1.6962025E+04',
# ...

# %%
setLattice(tao, **(importedDefaultSettings | {"L2PhaseSet" : -25} ) )

# %%
tao.cmd("show ele Q18601")
# Out:
# ['Element # 1749',
#  'Element Name: Q18601',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:601"',
#  'Key: Quadrupole',
#  'S_start, S:    789.684570,    789.791370',
#  'Ref_time_start, Ref_time:  2.634121E-06,  2.634478E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          =  7.6991010E-01 1/m^2    45  B1_GRADIENT                 = -2.2259615E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.6675893E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.6675894E+09 eV           GAMMA                       =  1.6962049E+04',
# ...

# %%
tao.cmd("set ele QUAD::* FIELD_MASTER = T")
# Out:
# []

# %%
setLattice(tao, **(importedDefaultSettings | {"L2PhaseSet" : -20} ) )

# %%
tao.cmd("show ele Q18601")
# Out:
# ['Element # 1749',
#  'Element Name: Q18601',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:601"',
#  'Key: Quadrupole',
#  'S_start, S:    789.684570,    789.791370',
#  'Ref_time_start, Ref_time:  2.634121E-06,  2.634478E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          =  7.6990927E-01 1/m^2    45  B1_GRADIENT                 = -2.2259615E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.6675987E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.6675987E+09 eV           GAMMA                       =  1.6962068E+04',
# ...

# %%
## Test new built-in function

# %%
tao = initializeTao(

    inputBeamFilePathSuffix = inputBeamFilePathSuffix,
    
    csrTF = csrTF,
    numMacroParticles=1e5,
    scratchPath = "/tmp",
    randomizeFileNames = True
)

setLattice(tao, **importedDefaultSettings)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR on
# Overwriting lattice with setLattice() defaults
# No defaults file provided to setLattice(). Using setLattice_configs/defaults.yml
# Number of macro particles = 100000.0
# Beam created, written to /tmp/beams/activeBeamFile_13119485922884815723.h5, and reinit to tao

# %%
tao.cmd("show ele Q18501")
# Out:
# ['Element # 1748',
#  'Element Name: Q18501',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:501"',
#  'Key: Quadrupole',
#  'S_start, S:    777.340170,    777.446970',
#  'Ref_time_start, Ref_time:  2.592945E-06,  2.593301E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          = -7.6880833E-01 1/m^2    45  B1_GRADIENT                 =  2.1855405E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.5223916E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.5223917E+09 eV           GAMMA                       =  1.6677904E+04',
# ...

# %%
setLattice(tao, **(importedDefaultSettings | {"L2PhaseSet" : -30} ) )

# %%
tao.cmd("show ele Q18501")
# Out:
# ['Element # 1748',
#  'Element Name: Q18501',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:501"',
#  'Key: Quadrupole',
#  'S_start, S:    777.340170,    777.446970',
#  'Ref_time_start, Ref_time:  2.592945E-06,  2.593301E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          = -7.6880833E-01 1/m^2    45  B1_GRADIENT                 =  2.1855430E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.5224013E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.5224013E+09 eV           GAMMA                       =  1.6677923E+04',
# ...

# %%
disableAutoQuadEnergyCompensation(tao)
setLattice(tao, **(importedDefaultSettings | {"L2PhaseSet" : -20} ) )

# %%
tao.cmd("show ele Q18501")
# Out:
# ['Element # 1748',
#  'Element Name: Q18501',
#  'Element Type:  "1.085Q4.31"',
#  'Element Alias:  "LI18:QUAD:501"',
#  'Key: Quadrupole',
#  'S_start, S:    777.340170,    777.446970',
#  'Ref_time_start, Ref_time:  2.592945E-06,  2.593301E-06',
#  '',
#  'Attribute values [Only non-zero values shown]:',
#  '    1  L                           =  1.0680000E-01 m',
#  '    4  K1                          = -7.6880639E-01 1/m^2    45  B1_GRADIENT                 =  2.1855430E+01 T/m',
#  '   10  FRINGE_TYPE                 =  None (1)               11  FRINGE_AT                   =  Both_Ends (3)',
#  '   13  SPIN_FRINGE_ON              =  T (1)',
#  '   17  STATIC_LINEAR_MAP           =  F (0)',
#  '   47  PTC_CANONICAL_COORDS        =  T (1)',
#  '   53  P0C                         =  8.5224228E+09 eV           BETA                        =  1.0000000E+00',
#  '   54  E_TOT                       =  8.5224228E+09 eV           GAMMA                       =  1.6677965E+04',
# ...
