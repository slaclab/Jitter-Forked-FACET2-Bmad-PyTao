# %%
from UTILITY_quickstart import *
# ?initializeTao
# Out:
# Signature:
# initializeTao(
#     filePath=None,
#     lastTrackedElement='end',
#     csrTF=False,
#     inputBeamFilePathSuffix=None,
#     numMacroParticles=None,
#     loadDefaultLatticeTF=True,
#     runImpactTF=False,
#     impactGridCount=32,
# )
# Docstring: <no docstring>
# File:      ~/Documents/SLAC/FACET2-Bmad-PyTao/UTILITY_quickstart.py
# Type:      function

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    #inputBeamFilePathSuffix = '/beams/L0AFEND_facet2-lattice.h5',

    #csrTF = True,
    numMacroParticles=1e4,
    #loadDefaultLatticeTF=False,

)

trackBeam(tao)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR off
# No defaults file provided to setLattice(). Using setLattice_defaults.yml
# Loading default setLattice() values
# Number of macro particles = 10000.0

# %%
P = getBeamAtElement(tao, "PENT")
display(plotMod(P, 'x', 'y',  bins=300))
display(plotMod(P, 'x', 'px',  bins=300))
display(plotMod(P, 'energy', 'x',  bins=300))
display(plotMod(P, 'delta_t', 'energy',  bins=300))
plt.clf()
print(P)
# Out:
# ParticleGroup with 10000 particles with total charge 2.0993254288279175e-09 C

# %%
PDrive, PWitness = getDriverAndWitness(P)

# %%
display(plotMod(PDrive, 'x', 'y',  bins=300))
display(plotMod(PDrive, 'x', 'px',  bins=300))
display(plotMod(PDrive, 'energy', 'x',  bins=300))
display(plotMod(PDrive, 'delta_t', 'energy',  bins=300))
plt.clf()
print(PDrive)
# Out:
# ParticleGroup with 7660 particles with total charge 1.6088354612952573e-09 C

# %%
display(plotMod(PWitness, 'x', 'y',  bins=300))
display(plotMod(PWitness, 'x', 'px',  bins=300))
display(plotMod(PWitness, 'energy', 'x',  bins=300))
display(plotMod(PWitness, 'delta_t', 'energy',  bins=300))
plt.clf()
print(PWitness)
# Out:
# ParticleGroup with 2340 particles with total charge 4.904899675326597e-10 C

# %%
#P.write("PENT.h5")

# %%
PDrive["mean_x"]
# Out:
# -7.106036540893663e-05

# %%
PWitness["mean_x"]
# Out:
# -0.0005713842329363793

# %%
tao.cmd("show matrix BEGBC20 PENT")
# Out:
# ['Symplectic Error:  3.29E-14',
#  '',
#  '     0.00435269    -1.90764202     0.00000000     0.00000000     0.00000000    -0.00005698   :  8.82386964E-18',
#  '     0.51743077     2.96996354    -0.00000000    -0.00000000     0.00000000    -0.00025375   : -6.74408629E-18',
#  '    -0.00000000    -0.00000000     0.21222511     2.52587307     0.00000000     0.00000000   :  5.86389427E-19',
#  '    -0.00000000    -0.00000000     0.05948257     5.41993092     0.00000000    -0.00000000   : -8.92562161E-20',
#  '    -0.00002838    -0.00065327     0.00000000     0.00000000     1.00000000    -0.00704085   : -1.69495577E-16',
#  '     0.00000000     0.00000000     0.00000000     0.00000000     0.00000000     1.00000000   :  0.00000000E+00']
