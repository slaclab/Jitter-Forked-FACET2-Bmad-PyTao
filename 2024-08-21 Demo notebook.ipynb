# %% [markdown]
# # Import and startup

# %%
from UTILITY_quickstart import *

# %%
tao = initializeTao(
    inputBeamFilePathSuffix = '/beams/nmmToL0AFEND_2bunch_2024-02-16Clean/2024-02-16_2bunch_1e5Downsample_nudgeWeights.h5',
    defaultsFile = "setLattice_defaults_2024-08-21_demo.yml",
    csrTF = True,
    numMacroParticles = 1e4,
)
# Out:
# Environment set to:  /Users/nmajik/Documents/SLAC/FACET2-Bmad-PyTao
# Tracking to end
# CSR on
# Overwriting lattice with setLattice() defaults
# Number of macro particles = 10000.0

# %% [markdown]
# # Transport matrices (to arb. order)

# %%
transportMatrix = getMatrix(tao, "BEGBC20", "ENDBC20", print = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6dd6">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a6dd6_row0_col0" class="data row0 col0" >-1.191035</td>
#       <td id="T_a6dd6_row0_col1" class="data row0 col1" >-2.165888</td>
#       <td id="T_a6dd6_row0_col2" class="data row0 col2" >-0.000000</td>
#       <td id="T_a6dd6_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_a6dd6_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_a6dd6_row0_col5" class="data row0 col5" >0.052089</td>
#     </tr>
#     <tr>
#       <td id="T_a6dd6_row1_col0" class="data row1 col0" >-0.193287</td>
#       <td id="T_a6dd6_row1_col1" class="data row1 col1" >-1.191097</td>
#       <td id="T_a6dd6_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_a6dd6_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a6dd6_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_a6dd6_row1_col5" class="data row1 col5" >0.004594</td>
#     </tr>
#     <tr>
#       <td id="T_a6dd6_row2_col0" class="data row2 col0" >-0.000000</td>
#       <td id="T_a6dd6_row2_col1" class="data row2 col1" >-0.000000</td>
#       <td id="T_a6dd6_row2_col2" class="data row2 col2" >-0.495393</td>
#       <td id="T_a6dd6_row2_col3" class="data row2 col3" >9.226548</td>
#       <td id="T_a6dd6_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_a6dd6_row2_col5" class="data row2 col5" >-0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a6dd6_row3_col0" class="data row3 col0" >-0.000000</td>
#       <td id="T_a6dd6_row3_col1" class="data row3 col1" >-0.000000</td>
#       <td id="T_a6dd6_row3_col2" class="data row3 col2" >-0.081773</td>
#       <td id="T_a6dd6_row3_col3" class="data row3 col3" >-0.495595</td>
#       <td id="T_a6dd6_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_a6dd6_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_a6dd6_row4_col0" class="data row4 col0" >-0.004596</td>
#       <td id="T_a6dd6_row4_col1" class="data row4 col1" >-0.052093</td>
#       <td id="T_a6dd6_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_a6dd6_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a6dd6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_a6dd6_row4_col5" class="data row4 col5" >-0.007197</td>
#     </tr>
#     <tr>
#       <td id="T_a6dd6_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_a6dd6_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_a6dd6_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_a6dd6_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_a6dd6_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_a6dd6_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Track and plot

# %%
trackBeam(tao)

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'x', 'y',  bins=300));
plt.clf()

# %% [markdown]
# # Change a magnet

# %%
setQuadkG(tao, "Q0FF", 0)
trackBeam(tao)

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'x', 'y',  bins=300));

# %% [markdown]
# # Change linac phase

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'z', 'pz',  bins=300));

# %%
setLinacPhase(tao, "L2", -37)
trackBeam(tao)

# %%
P =  getBeamAtElement(tao, "PENT")

display(plotMod(P, 'z', 'pz',  bins=300));
